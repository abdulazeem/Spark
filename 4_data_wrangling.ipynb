# %% [markdown]
# # Data Wrangling with Spark
#
# This is the code used in the previous screencast. Run each code cell to understand what the code does and how it works.
#
# These first three cells import libraries, instantiate a SparkSession, and then read in the data set

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import desc
from pyspark.sql.functions import asc
from pyspark.sql.functions import sum as Fsum

import datetime

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
spark = SparkSession \
    .builder \
    .appName("Wrangling Data") \
    .getOrCreate()

# %%
path = "data/sparkify_log_small.json"
user_log = spark.read.json(path)

# %% [markdown]
# # Data Exploration
#
# The next cells explore the data set.

# %%
user_log.take(5)
# Out:
# [Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046'),
#  Row(artist='Lily Allen', auth='Logged In', firstName='Elizabeth', gender='F', itemInSession=7, lastName='Chase', length=195.23873, level='free', location='Shreveport-Bossier City, LA', method='PUT', page='NextSong', registration=1512718541284, sessionId=5027, song='Cheryl Tweedy', status=200, ts=1513720878284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='1000'),
#  Row(artist='Cobra Starship Featuring Leighton Meester', auth='Logged In', firstName='Vera', gender='F', itemInSession=6, lastName='Blackwell', length=196.20526, level='paid', location='Racine, WI', method='PUT', page='NextSong', registration=1499855749284, sessionId=5516, song='Good Girls Go Bad (Feat.Leighton Meester) (Album Version)', status=200, ts=1513720881284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"', userId='2219'),
#  Row(artist='Alex Smoke', auth='Logged In', firstName='Sophee', gender='F', itemInSession=8, lastName='Barker', length=405.99465, level='paid', location='San Luis Obispo-Paso Robles-Arroyo Grande, CA', method='PUT', page='NextSong', registration=1513009647284, sessionId=2372, song="Don't See The Point", status=200, ts=1513720905284, userAgent='"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='2373'),
#  Row(artist=None, auth='Logged In', firstName='Jordyn', gender='F', itemInSession=0, lastName='Jones', length=None, level='free', location='Syracuse, NY', method='GET', page='Home', registration=1513648531284, sessionId=1746, song=None, status=200, ts=1513720913284, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"', userId='1747')]

# %%
user_log.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
user_log.describe().show()
# Out:
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+
# |summary|           artist|      auth|firstName|gender|     itemInSession|lastName|           length|level|    location|method|   page|        registration|         sessionId|    song|            status|                  ts|           userAgent|            userId|
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+
# |  count|             8347|     10000|     9664|  9664|             10000|    9664|             8347|10000|        9664| 10000|  10000|                9664|             10000|    8347|             10000|               10000|                9664|             10000|
# |   mean|            461.0|      null|     null|  null|           19.6734|    null|249.6486587492503| null|        null|  null|   null|1.504695369588739...|         4436.7511|Infinity|          202.8984|  1.5137859954164E12|                null|1442.4413286423842|
# | stddev|            300.0|      null|     null|  null|25.382114916132597|    null|95.00437130781461| null|        null|  null|   null|  8.47314252131657E9|2043.1281541827557|     NaN|18.041791154505876|3.2908288623601213E7|                null| 829.8909432082613|
# |    min|              !!!|     Guest|   Aakash|     F|                 0| Acevedo|          1.12281| free|Aberdeen, WA|   GET|  About|       1463503881284|                 9|      #1|               200|       1513720872284|"Mozilla/5.0 (Mac...|                  |
# |    max|ÃÂlafur Arnalds|Logged Out|     Zoie|     M|               163|  Zuniga|        1806.8371| paid|    Yuma, AZ|   PUT|Upgrade|       1513760702284|              7144|wingless|               404|       1513848349284|Mozilla/5.0 (comp...|               999|
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+

# %%
user_log.describe("artist").show()
# Out:
# +-------+-----------------+
# |summary|           artist|
# +-------+-----------------+
# |  count|             8347|
# |   mean|            461.0|
# | stddev|            300.0|
# |    min|              !!!|
# |    max|ÃÂlafur Arnalds|
# +-------+-----------------+

# %%
user_log.describe("sessionId").show()
# Out:
# +-------+------------------+
# |summary|         sessionId|
# +-------+------------------+
# |  count|             10000|
# |   mean|         4436.7511|
# | stddev|2043.1281541827557|
# |    min|                 9|
# |    max|              7144|
# +-------+------------------+

# %%
user_log.count()
# Out:
# 10000

# %%
user_log.describe().show()
# Out:
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+
# |summary|           artist|      auth|firstName|gender|     itemInSession|lastName|           length|level|    location|method|   page|        registration|         sessionId|    song|            status|                  ts|           userAgent|            userId|
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+
# |  count|             8347|     10000|     9664|  9664|             10000|    9664|             8347|10000|        9664| 10000|  10000|                9664|             10000|    8347|             10000|               10000|                9664|             10000|
# |   mean|            461.0|      null|     null|  null|           19.6734|    null|249.6486587492503| null|        null|  null|   null|1.504695369588739...|         4436.7511|Infinity|          202.8984|  1.5137859954164E12|                null|1442.4413286423842|
# | stddev|            300.0|      null|     null|  null|25.382114916132597|    null|95.00437130781461| null|        null|  null|   null|  8.47314252131657E9|2043.1281541827557|     NaN|18.041791154505876|3.2908288623601213E7|                null| 829.8909432082613|
# |    min|              !!!|     Guest|   Aakash|     F|                 0| Acevedo|          1.12281| free|Aberdeen, WA|   GET|  About|       1463503881284|                 9|      #1|               200|       1513720872284|"Mozilla/5.0 (Mac...|                  |
# |    max|ÃÂlafur Arnalds|Logged Out|     Zoie|     M|               163|  Zuniga|        1806.8371| paid|    Yuma, AZ|   PUT|Upgrade|       1513760702284|              7144|wingless|               404|       1513848349284|Mozilla/5.0 (comp...|               999|
# +-------+-----------------+----------+---------+------+------------------+--------+-----------------+-----+------------+------+-------+--------------------+------------------+--------+------------------+--------------------+--------------------+------------------+

# %%
user_log.select("page").dropDuplicates().sort("page").show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |           About|
# |       Downgrade|
# |           Error|
# |            Help|
# |            Home|
# |           Login|
# |          Logout|
# |        NextSong|
# |   Save Settings|
# |        Settings|
# |Submit Downgrade|
# |  Submit Upgrade|
# |         Upgrade|
# +----------------+

# %%
user_log.select("page").dropDuplicates().sort("firstname").show()
# Out:
# +----------------+
# |            page|
# +----------------+
# |           Login|
# |  Submit Upgrade|
# |          Logout|
# |            Help|
# |         Upgrade|
# |   Save Settings|
# |            Home|
# |        Settings|
# |       Downgrade|
# |Submit Downgrade|
# |        NextSong|
# |           About|
# |           Error|
# +----------------+

# %%
user_log.select(["userId", "firstname", "page", "song"]).where(user_log.userId == "1046").collect()
# Out:
# [Row(userId='1046', firstname='Kenneth', page='NextSong', song='Christmas Tears Will Fall'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Be Wary Of A Woman'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Public Enemy No.1'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Reign Of The Tyrants'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Father And Son'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='No. 5'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Seventeen'),
#  Row(userId='1046', firstname='Kenneth', page='Home', song=None),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='War on war'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Killermont Street'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Black & Blue'),
#  Row(userId='1046', firstname='Kenneth', page='Logout', song=None),
#  Row(userId='1046', firstname='Kenneth', page='Home', song=None),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Heads Will Roll'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Bleed It Out [Live At Milton Keynes]'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Clocks'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Love Rain'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song="Ry Ry's Song (Album Version)"),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='The Invisible Man'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Ask The Mountains'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Given Up (Album Version)'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='El Cuatrero'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Hero/Heroine'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Spring'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Rising Moon'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Tough Little Boys'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song="Qu'Est-Ce Que T'Es Belle"),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Secrets'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Under The Gun')]

# %%
user_log.select('time')

# %%
user_log.select(["userId", "firstname", "page", "song"]).where(user_log.page == "NextSong").collect()
# Out:
# [Row(userId='1046', firstname='Kenneth', page='NextSong', song='Christmas Tears Will Fall'),
#  Row(userId='1000', firstname='Elizabeth', page='NextSong', song='Cheryl Tweedy'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Good Girls Go Bad (Feat.Leighton Meester) (Album Version)'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song="Don't See The Point"),
#  Row(userId='1162', firstname='Paige', page='NextSong', song='Smoke Buddah'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='On My Own'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song="Heart Of The City (Ain't No Love)"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Bring Me To Life'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Laura'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Here Without You'),
#  Row(userId='2146', firstname='Malachi', page='NextSong', song='This Old House w/ When The Saints Medley'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Follow Me (Club Mix)'),
#  Row(userId='2904', firstname='Elena', page='NextSong', song='Undo'),
#  Row(userId='597', firstname='Alexander', page='NextSong', song='Sheebeg And Sheemore'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Far Away (Album Version)'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Be Wary Of A Woman'),
#  Row(userId='1162', firstname='Paige', page='NextSong', song="I'd Hate To Be You When People Find Out What This Song Is About (Album)"),
#  Row(userId='2942', firstname='Ryder', page='NextSong', song='Oh Jungleland'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song="Captain Kelly's Kitchen"),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='CIEÃ\x83Â\x91'),
#  Row(userId='2887', firstname='Lillian', page='NextSong', song='Red Light'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Without You (LP Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Message In A Bottle'),
#  Row(userId='597', firstname='Alexander', page='NextSong', song="Quelqu'un M'a Dit (Album Version)"),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Bubbles'),
#  Row(userId='429', firstname='Cesar', page='NextSong', song='Entertainment Value (2006 Digital Remaster)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='DONTTRUSTME [BENNYBLANCOREMIX] FEATURINGKIDCUDI (Explicit Bonus Version)'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='Haunted'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Public Enemy No.1'),
#  Row(userId='577', firstname='Caitlin', page='NextSong', song="Ghosts 'n' Stuff (Original Instrumental Mix)"),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Who By Fire'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Runaway Love'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Stuck In The Moment'),
#  Row(userId='2085', firstname='Lucas', page='NextSong', song='Libros Sapienciales'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Cuts Marked In The March Of Men'),
#  Row(userId='2887', firstname='Lillian', page='NextSong', song='La 11Eme Marche (Alexander Kowalski Remix)'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Dope Boys'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Australia (Album)'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Satellites'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Valentine'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Video Killed The Radio Star'),
#  Row(userId='2942', firstname='Ryder', page='NextSong', song='Sweet And Wild'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Crying In The Rain (1987 Version) (2007 Digital Remaster)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Brat Pack'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song="Nothin' On You [feat. Bruno Mars] (Album Version)"),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Reign Of The Tyrants'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='Around The Bend'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Cyanide'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Slave'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Crazy Faith'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Unite (2009 Digital Remaster)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Manajah'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='The Pretender'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song="Nothin' On You [feat. Bruno Mars] (Album Version)"),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Father And Son'),
#  Row(userId='2942', firstname='Ryder', page='NextSong', song='What Are You Looking For'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='The Chills'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='Que Se Sepa'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Your Man'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Banned Announcement'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Trojan Horse'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Like A Virgin (Edit Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Joy'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='SinceritÃ\x83Â© Et Jalousie'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='See You In Hell'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='No. 5'),
#  Row(userId='481', firstname='Pierre', page='NextSong', song='Vibrator'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song="Nothin' Bout Love Makes Sense"),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Manhattan'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Crazy He Calls Me'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Californication (Album Version)'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song="Don't Let It Get You Down"),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Conant Gardens'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Eriatarka'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Una Confusion'),
#  Row(userId='184', firstname='Kara', page='NextSong', song='LoveStoned/I Think She Knows'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='Numbers'),
#  Row(userId='1046', firstname='Kenneth', page='NextSong', song='Seventeen'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Feel It All Around'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='To Hell With The Devil'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song="Say It Ain't So"),
#  Row(userId='714', firstname='William', page='NextSong', song='Down By The Water'),
#  Row(userId='2902', firstname='Mya', page='NextSong', song='Stay With Me (Baby)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Get Out (Album Version)'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Black Like Me'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Everything I Cannot See'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Fire Burning'),
#  Row(userId='757', firstname='Katherine', page='NextSong', song='TÃ\x83Âºl sok a kirÃ\x83Â¡ly'),
#  Row(userId='1267', firstname='James', page='NextSong', song='Use Somebody'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Wot'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Que Bonito (Version Ranchera)'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='What Would The Community Think'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Are You Here'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='I.O.U. Me'),
#  Row(userId='757', firstname='Katherine', page='NextSong', song='La casa de Dios'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Hold You In My Arms'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Unprotected Sex With Multiple Partners'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Lola'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='P.I.M.P.'),
#  Row(userId='184', firstname='Kara', page='NextSong', song='Stronger'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Sehr kosmisch'),
#  Row(userId='1267', firstname='James', page='NextSong', song='Carolina Rain'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Weak'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Pictures Of You'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Infinity'),
#  Row(userId='2373', firstname='Sophee', page='NextSong', song='Congratulations_ I Hate You'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='FANTASY'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Hold On (LP Version)'),
#  Row(userId='656', firstname='Sophia', page='NextSong', song='White Sky'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Stumptown'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Air A Danser'),
#  Row(userId='2882', firstname='Zimora', page='NextSong', song='Armistice'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Boje kianog neba'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song='A Dead Current'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Tiger Feet'),
#  Row(userId='184', firstname='Kara', page='NextSong', song='California Stars (LP Version)'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='I C Love Affair'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Say Hello (Angello & Ingrosso Remix)'),
#  Row(userId='1312', firstname='Connor', page='NextSong', song='Accident Waiting To Happen (Red Stars Version)'),
#  Row(userId='1267', firstname='James', page='NextSong', song='Home'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='To Know Him Is To Love Him'),
#  Row(userId='656', firstname='Sophia', page='NextSong', song='Hochmah (Interlude)'),
#  Row(userId='2853', firstname='Riley', page='NextSong', song='Words So Leisured'),
#  Row(userId='1396', firstname='Elizabeth', page='NextSong', song='Generation Nintendo'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='The Flowers (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='The Girl Got Hot'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='When The Sun Comes Down'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song='Heretic Pride'),
#  Row(userId='2882', firstname='Zimora', page='NextSong', song="The Boy's Gone (Live On Earth Version)"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Pharaoh'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Ugly Girls'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Whole World'),
#  Row(userId='2853', firstname='Riley', page='NextSong', song='22'),
#  Row(userId='1312', firstname='Connor', page='NextSong', song='Bubble Toes'),
#  Row(userId='184', firstname='Kara', page='NextSong', song='StreetLove'),
#  Row(userId='1267', firstname='James', page='NextSong', song='Distance Will Save Us'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Heretics'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Happy Birthday To Me'),
#  Row(userId='2779', firstname='Eliana', page='NextSong', song='Jungla de Pasto'),
#  Row(userId='2018', firstname='Naomi', page='NextSong', song='A Bitch Iz A Bitch (Explicit) (Digitally Remastered 02)'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Such Great Heights'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='All I Ever Wanted'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song="Don't Matter"),
#  Row(userId='864', firstname='Trayton', page='NextSong', song="Kiss Me_ I'm Gone"),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Alexithymia'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song="Hips Don't Lie (featuring Wyclef Jean)"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Shots'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Kiss With A Fist'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song="Let's Talk About Girls"),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Dope Boys'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Because Of You (Album Version)'),
#  Row(userId='2018', firstname='Naomi', page='NextSong', song='Believe'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='Write This Down'),
#  Row(userId='2958', firstname='Ayman', page='NextSong', song='Heads Will Roll'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Set Me Free'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song='Bermuda'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Coleccionista De Canciones'),
#  Row(userId='1267', firstname='James', page='NextSong', song='NiÃ\x83Â±o Soldado'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Pursuit Of Happiness (nightmare)'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Steady Mobbin'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Lazarus (Album Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Summer Girls'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='Face Down (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Waimea Bay'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Bring Me To Life'),
#  Row(userId='2958', firstname='Ayman', page='NextSong', song='Without A Sound'),
#  Row(userId='1267', firstname='James', page='NextSong', song='A Better Place_ A Better Time (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Reception Fades'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='When I Grow Up'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='The Kissaway (LP Version)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Love You To Death (Album Version)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Walk Of Life'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='De Noite Na Cama'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='Heartbreak Warfare'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='End This Day'),
#  Row(userId='2416', firstname='Sophia', page='NextSong', song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)'),
#  Row(userId='541', firstname='Angel', page='NextSong', song="Don't Matter"),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Lava Lava'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Rock'),
#  Row(userId='1478', firstname='Natasha', page='NextSong', song='Rehab'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song="You've Got The Love"),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='If You Wanted A Song Written About You_ All You Had To Do Was Ask (Album)'),
#  Row(userId='816', firstname='Ava', page='NextSong', song="Pimpin'"),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Independence Day'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='Expendable Youth'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Scotty (explicit album version)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='The Climb'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Moppitopit: TÃ\x83Â¤htiÃ\x83Â¤ silmissÃ\x83Â¤ni nÃ\x83Â¤Ã\x83Â¤n (2006 Digital Remaster)'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song='T.N.T. For The Brain (112 Bpm) (Radio Edit)'),
#  Row(userId='1267', firstname='James', page='NextSong', song="Jesu_ Joy Of Man's Desiring (Featuring Lili Haydn) (Album Version)"),
#  Row(userId='2416', firstname='Sophia', page='NextSong', song='Outta Control'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Our Lives'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song='Road To Nowhere'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song="Johnny Jump Up/Morrison's Jig"),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Respectness (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Under The Milky Way'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Dial Up Infinity'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='Geek In The Pink (Album Version)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='On Melancholy Hill'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Sea Anemone'),
#  Row(userId='1035', firstname='Connor', page='NextSong', song="Throw Some D's Remix"),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Wordz Of Wizdom'),
#  Row(userId='1267', firstname='James', page='NextSong', song='I'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Pluck'),
#  Row(userId='950', firstname='Skyler', page='NextSong', song='Bruised (Snakes Remix)'),
#  Row(userId='1267', firstname='James', page='NextSong', song='Faheem'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Friend (Album Version)'),
#  Row(userId='1258', firstname='Sam', page='NextSong', song='Marry Me'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Mass Appeal (Explicit)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='In Our Blood'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Invalid'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='The Upstairs Room'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Safe'),
#  Row(userId='2201', firstname='Angelina', page='NextSong', song='Lord Have Mercy (Amended Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song="I'll Be Your Man"),
#  Row(userId='1263', firstname='Iyana', page='NextSong', song='Broken'),
#  Row(userId='2818', firstname='Sydney', page='NextSong', song='Sehr kosmisch'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='I Believe (Edit)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Somebody To Love'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Last Tango In Paris'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='One More Chance (Album Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Intervalo'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Kaaos ei karkaa'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Dog Problems (Live)'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Dog Days Are Over (Radio Edit)'),
#  Row(userId='2201', firstname='Angelina', page='NextSong', song='Electric Pulse (Album Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='So It Goes'),
#  Row(userId='1061', firstname='Gabriel', page='NextSong', song='Neon Bible'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Fireflies'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='A Little More (Lay It Down Album Version)'),
#  Row(userId='700', firstname='Jack', page='NextSong', song='Good Life'),
#  Row(userId='2201', firstname='Angelina', page='NextSong', song='Chico ProblemÃ\x83Â¡tico'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Little Nature'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Pitter-Pat'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Satellite'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Teach Me How To Dougie'),
#  Row(userId='623', firstname='Ambree', page='NextSong', song="I'm Done"),
#  Row(userId='1495', firstname='Alfredo', page='NextSong', song='All The Young Dudes'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='21 Guns [feat. Green Day & The Cast Of American Idiot] (Album Version)'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='Helena (So Long & Goodnight) (Album Version)'),
#  Row(userId='1952', firstname='Hassan', page='NextSong', song='Rocky Took A Lover'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Shiver'),
#  Row(userId='2812', firstname='Sarah', page='NextSong', song='Takillyn (Esthabon)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='The Church Of Hot Addiction (Album Version)'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Gia'),
#  Row(userId='623', firstname='Ambree', page='NextSong', song='Still Alive'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='No Tiene Sentido'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Voodoo'),
#  Row(userId='2201', firstname='Angelina', page='NextSong', song='Far Away (Album Version)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Teardrops Will Kiss The Morning Dew'),
#  Row(userId='700', firstname='Jack', page='NextSong', song='Painting by Chagall'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='I Want You'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Come On Come On (Digital Album Version)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Shoulders & Arms'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Stickwitu'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Revolution'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Rebelles'),
#  Row(userId='2201', firstname='Angelina', page='NextSong', song='Hold On'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song="Salgo Pa' La Calle"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Ghost Of The Navigator'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Wet!Wet!Wet!'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='Not Fair'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='I Melt With You'),
#  Row(userId='2528', firstname='Silas', page='NextSong', song="Nobody Don't Dance No More (feat. NO)"),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Suddenly I See (Radio Version)'),
#  Row(userId='7', firstname='Maximo', page='NextSong', song='Misfits'),
#  Row(userId='47', firstname='Levi', page='NextSong', song='Tetrispack'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Where Is Everybody?'),
#  Row(userId='392', firstname='Khori', page='NextSong', song='I Wanna Be Your Limousine'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='El Aparato'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='A Nightmare To Remember (Album Version)'),
#  Row(userId='231', firstname='William', page='NextSong', song='Que dira el santo padre'),
#  Row(userId='2897', firstname='Ethan', page='NextSong', song='Intuition'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='My Perfect Cousin'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Glow'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Jump Around (LP Version)'),
#  Row(userId='2528', firstname='Silas', page='NextSong', song='She Loves You'),
#  Row(userId='392', firstname='Khori', page='NextSong', song='Mundo silencio'),
#  Row(userId='7', firstname='Maximo', page='NextSong', song='Keep You'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Secrets'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Shadow Of Your Love (Remixed By Gilby Clarke Featuring Tracii Guns)'),
#  Row(userId='231', firstname='William', page='NextSong', song='Opposite Of Adults'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Invalid'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='Home (Live)'),
#  Row(userId='421', firstname='Johanna', page='NextSong', song='Said What You Mean'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Breathe . Something/Stellar STar'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Paper ClichÃ\x83Â© (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='You Only Live Once'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Fag Hag'),
#  Row(userId='231', firstname='William', page='NextSong', song='Viejo'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Video Killed The Radio Star'),
#  Row(userId='392', firstname='Khori', page='NextSong', song='Girlfriend (Radio Edit)'),
#  Row(userId='1152', firstname='Dominique', page='NextSong', song='Feeling Good'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Televators'),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='Mony Mony (Downtown Mix)'),
#  Row(userId='2219', firstname='Vera', page='NextSong', song="You've Got The Love"),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Pocket Porn (1990)'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='The Mirror Conspiracy'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Lift Me Up'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song="Fire Coming Out Of The Monkey's Head"),
#  Row(userId='2219', firstname='Vera', page='NextSong', song='Where Is My Mind?'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Touch Me In The Morning'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Die Die Die'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song="Nothin' On You [feat. Bruno Mars] (Album Version)"),
#  Row(userId='2176', firstname='Saya', page='NextSong', song='Revelry'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Colour My World (Remastered LP Version #2/GH)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Thank You'),
#  Row(userId='1110', firstname='Hunter', page='NextSong', song='Next Evil'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song="Aces & 8's (Explicit LP Version)"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='What Are We Fighting For?'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='O Segundo Sol'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Waiting For Tide'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='The Invisible Man'),
#  Row(userId='1110', firstname='Hunter', page='NextSong', song='Pursuit Of Happiness (nightmare)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Breakeven'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Highway 20 Ride (Album)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='To Be Remembered'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Caravan'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='I Need Love'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Stripper Vicar'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song="You Can't Hurry Love"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Cousins'),
#  Row(userId='2636', firstname='Ella', page='NextSong', song='My Body (Remastered Single Version)'),
#  Row(userId='827', firstname='Landon', page='NextSong', song='Tu Ventana'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Yo te dirÃ\x83Â©'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song="What's It Gonna Be"),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Crazy Bitch (Album Version)'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song="Beggin'"),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Heavy Soul '),
#  Row(userId='1633', firstname='Jose', page='NextSong', song='Nazanin'),
#  Row(userId='438', firstname='Addison', page='NextSong', song='Black Refuge'),
#  Row(userId='827', firstname='Landon', page='NextSong', song='Maker (1999 Digital Remaster)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Bad Moon Rising'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Fim De Caso'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='An CailÃ\x83Â\xadn Gaelach'),
#  Row(userId='1633', firstname='Jose', page='NextSong', song='Pink Ego Box'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Bette Davis Eyes'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Shiller'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='La Fuerza Del Destino'),
#  Row(userId='2922', firstname='Abraham', page='NextSong', song='Tangerine  (Album Version)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Something (Album Version)'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Like Light To The Flies'),
#  Row(userId='2018', firstname='Naomi', page='NextSong', song='Yeah Yeah'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Hug'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Tennessee Sucks'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Come In With The Rain'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='BedRock (Radio Edit) (feat.Lloyd)'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Cry Me A River'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Everybody Needs A 303'),
#  Row(userId='553', firstname='Easton', page='NextSong', song='Almost Grown'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Lovestain'),
#  Row(userId='1712', firstname='Russell', page='NextSong', song='Mumbles'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Television Rules The Nation / Crescendolls'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Stay'),
#  Row(userId='2038', firstname='John', page='NextSong', song='Friend Of A Friend'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Potential'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Soul Of A Vagabond'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Fix You'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Lively Up Yourself'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Garden Of Eden'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Praise You In This Storm (Medium w/o background vocals)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Moron Brothers (live)'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Fix You'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='When This World Fades'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Left With Alibis And Lying Eyes'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Stupid In Love'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='I Need You (Album Version)'),
#  Row(userId='999', firstname='Andy', page='NextSong', song='Moving Forward (feat. Late_ M.E.N.I.S. & Caper)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='ReprÃ\x83Â©sente'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Smile Version Revisited (Mark Ronson Remix) (Explicit)'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Sweet Thursday'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Two Heads One Pillow'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Stickin In My Eye'),
#  Row(userId='1264', firstname='Carina', page='NextSong', song='My Heart Will Go On'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='When The World Was Woken (2002 Digital Remaster)'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Under The Radar'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Fuck Kitty'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Losing My Mind'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Tengo Hambre'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Son Of Dragon'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Moonshine'),
#  Row(userId='1429', firstname='Valentina', page='NextSong', song="Can't Stop"),
#  Row(userId='999', firstname='Andy', page='NextSong', song='Backdrifts'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Clocks'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Microdaze'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='The Gift'),
#  Row(userId='1264', firstname='Carina', page='NextSong', song="Atomic '98 (Xenomania Mix)"),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Thorn In My Pride'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song="Who's Real"),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Good Love Is On The Way'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='They Might Follow You'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='How Come'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Everybody Everybody'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Eat Yourself'),
#  Row(userId='1264', firstname='Carina', page='NextSong', song='I Like The Way (Amended Version)'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Air Mattress'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Hello Good Morning'),
#  Row(userId='1349', firstname='Azure', page='NextSong', song='Play Dirty (24-Bit Digitally Remastered 05)'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='You Could Be Mine'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Rip Tide'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song="Let's Spend The Night Together (1999 Digital Remaster)"),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='No Hay Nadie Como TÃ\x83Âº'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Intifada'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Wheel Of Fortune'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Bring Me To Life'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Gears'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Despues'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Fortress Around Your Heart'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Sinisten tÃ\x83Â¤htien alla'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Silence Sea and Sky'),
#  Row(userId='1349', firstname='Azure', page='NextSong', song='Maybe So Maybe No'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Where The Hood At'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Crack A Bottle'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='Mandarine Girl'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Flake'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='The Foundation'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Fireflies'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Home Is Where The Heart Is'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Move Shake Drop Remix'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Nah!'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Fuck Kitty'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Use Somebody'),
#  Row(userId='1349', firstname='Azure', page='NextSong', song='Sarcophagus'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Southside Remix'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Save Tonight'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Exploding/Reloading'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Adicto Al Dolor (Lagrimas)'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Soul Makossa'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Love'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='How Do You?'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='The Deepest Blues Are Black'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Warning (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Love Of My Life (1993 Digital Remaster)'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Hoe'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Tacobel Canon'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Simple  (LP Version)'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song="It's Just A Thought"),
#  Row(userId='1349', firstname='Azure', page='NextSong', song='La Zafra'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Look Up'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Everythings Just Wonderful'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='U Smile'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='Hold On (LP Version)'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Trouble Dub - FAMS Mix'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='To Meet You'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Teenage Dirtbag'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Moth'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='CHILDREN'),
#  Row(userId='1187', firstname='Addison', page='NextSong', song='Malibu'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Down In The Valley Woe'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Vietnam'),
#  Row(userId='890', firstname='Xzavier', page='NextSong', song='Sr. Cobranza'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='In The Mirror'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song="What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)"),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Girl U Want (Live)'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='The World Is Mine'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='How Long'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='A rodar mi vida'),
#  Row(userId='1790', firstname='Cesar', page='NextSong', song='Hello'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Friday Night'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Falling'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Champion'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='Heartbeats (Live)'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Africa'),
#  Row(userId='1187', firstname='Addison', page='NextSong', song='Do You Remember The First Time?'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='The Crow & The Butterfly (Album Version)'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Ghost Of A Good Thing'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Treat Her Like A Lady'),
#  Row(userId='890', firstname='Xzavier', page='NextSong', song="Do You Think I'm Spooky?"),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Teach Me How To Dougie'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Sugar Ray (LP Version)'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='House Of Jealous Lovers'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Gives You Hell'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='Creil City'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='The Choice Is Yours'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='When Will They Shoot? (Edited)'),
#  Row(userId='1349', firstname='Azure', page='NextSong', song='How Could An Angel Break My Heart'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Seven Nation Army'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Nothing Better (Album)'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Hand Grenade'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Carrion'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Robot Rock'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='SeÃ\x83Â±orita'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='The Seventh Revelation'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Give It'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song="Don't Cut Me Down"),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Transmission'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Brasileirinho'),
#  Row(userId='1187', firstname='Addison', page='NextSong', song='Savage Circle'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Epilogue'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='FotografÃ\x83Â\xada'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song="Everybody Thinks You're An Angel"),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Sound Advice'),
#  Row(userId='1949', firstname='Joshua', page='NextSong', song='Almaz'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='Crucificame'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Undo'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Save The Last Dance For Me [Ralphi Rosario Anthomic Vocal]'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Look Me In The Eye'),
#  Row(userId='160', firstname='Toren', page='NextSong', song='Little Bitch'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='This Time Around'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Barnowl'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Secret'),
#  Row(userId='890', firstname='Xzavier', page='NextSong', song="Daddy's Eyes"),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Mutt'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='If You Want To Sing Out_ Sing Out'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Santa Monica'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='Take Me In Your Arms (Rock Me A Little While)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Calm Down Baby'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='OMG'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Love Of My Life (1993 Digital Remaster)'),
#  Row(userId='2993', firstname='Annalise', page='NextSong', song='Stork & Owl'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Blue Magic'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Fourteen Wives'),
#  Row(userId='2851', firstname='Alexander', page='NextSong', song='I Walk The Line'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Riding With Private Malone'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Let Him Fly'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Fuck Kitty'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Feuer Frei'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='How Could I Help But Love You'),
#  Row(userId='2123', firstname='Hendrik', page='NextSong', song='Better To Reign In Hell'),
#  Row(userId='2109', firstname='Kyle', page='NextSong', song='La chica de Ipanema'),
#  Row(userId='1583', firstname='Javon', page='NextSong', song='King Of Wishful Thinking'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Eye On The World'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='No Envy No Fear'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='That Was Just A Dream'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song="I'm In Chains"),
#  Row(userId='648', firstname='Darrian', page='NextSong', song="I'll Go On Loving You"),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='London Dungeon'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='House Of Cards'),
#  Row(userId='2993', firstname='Annalise', page='NextSong', song='Message To Love'),
#  Row(userId='2851', firstname='Alexander', page='NextSong', song='The Other Side'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Cosmic Love'),
#  Row(userId='622', firstname='Christopher', page='NextSong', song="You're The One"),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Canada'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='I Feel Better'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='God Wears Gucci'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Last Exit'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Use Somebody'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Miseria Cantare--The Beginning'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='Breathe'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Keep Quiet'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='The Tip Of The Iceberg'),
#  Row(userId='321', firstname='Ryan', page='NextSong', song='Eye Candy'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Narcotic'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Love On The Rocks'),
#  Row(userId='648', firstname='Darrian', page='NextSong', song='Fuck Kitty'),
#  Row(userId='1952', firstname='Hassan', page='NextSong', song='It Feels So Good'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Good Times'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Seaside'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Where Eagles Dare'),
#  Row(userId='1806', firstname='Micheal', page='NextSong', song='Voices Of Violence (Album Version)'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Digital Love'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Animal'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Quicksand'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='So Easy'),
#  Row(userId='648', firstname='Darrian', page='NextSong', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  Row(userId='226', firstname='Abigail', page='NextSong', song='Big In Japan (Original)'),
#  Row(userId='35', firstname='Aimar', page='NextSong', song='Love And Destroy'),
#  Row(userId='108', firstname='Mason', page='NextSong', song='Creep (Explicit)'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Loretta'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Family Secret'),
#  Row(userId='2801', firstname='Wyatt', page='NextSong', song='Home'),
#  Row(userId='2533', firstname='Zachary', page='NextSong', song='Breaking the Waves'),
#  Row(userId='2993', firstname='Annalise', page='NextSong', song='Tive Sim'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Breakeven'),
#  Row(userId='2412', firstname='Greyson', page='NextSong', song='A New Way To Say Hooray!'),
# ...
#  Row(userId='2096', firstname='Stephanie', page='NextSong', song='Extraordinary'),
#  Row(userId='1077', firstname='Kaileigh', page='NextSong', song='The General'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Extremity Retained'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Guns Before Butter'),
#  Row(userId='2715', firstname='Caden', page='NextSong', song='Altar Particular'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Revelry'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song="Doin' Just Fine"),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='The Feel Good Drag'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='We Will Not Tolerate'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Elsewhere'),
#  Row(userId='2774', firstname='Santiago', page='NextSong', song='Bandy Riddles'),
#  Row(userId='512', firstname='Ashton', page='NextSong', song='Shiver'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='The Fool On The Hill'),
#  Row(userId='1077', firstname='Kaileigh', page='NextSong', song='Canada'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='I Put A Spell On You'),
#  Row(userId='748', firstname='Mason', page='NextSong', song='Tropicana'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Moi je'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Yer So Bad'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Strange Desire'),
#  Row(userId='2774', firstname='Santiago', page='NextSong', song='The Beer'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Late'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='No Surprise'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Blues Deluxe'),
#  Row(userId='2593', firstname='Rashaan', page='NextSong', song='Hate On Me'),
#  Row(userId='1077', firstname='Kaileigh', page='NextSong', song='Juego De Seduccion'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='March Of The Celts'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Dress'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Until It Sleeps'),
#  Row(userId='745', firstname='Autumn', page='NextSong', song="Rollin' (Air Raid Vehicle)"),
#  Row(userId='512', firstname='Ashton', page='NextSong', song="Medley: Stay/Let's Hang On/Opus 17 [Don't You Worry 'Bout Me/Bye_ Bye_ Baby]"),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Fleas'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Redemption'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Exceeder'),
#  Row(userId='420', firstname='Jakobi', page='NextSong', song='Kiss Me Where It Smells Funny'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='The Penance'),
#  Row(userId='2593', firstname='Rashaan', page='NextSong', song='Strong Enough'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Electricity'),
#  Row(userId='1077', firstname='Kaileigh', page='NextSong', song='When The Sun Comes Down'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Way Over Yonder In The Minor Key'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Return The Favour'),
#  Row(userId='2954', firstname='Mark', page='NextSong', song="Let's Live For Today"),
#  Row(userId='512', firstname='Ashton', page='NextSong', song="That'll Make You Wanna Drink"),
#  Row(userId='2872', firstname='Kevin', page='NextSong', song='Hey_ Soul Sister'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Godspeed'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Aces High'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Lady'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Greece 2000'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Howlin\x19 For You'),
#  Row(userId='2743', firstname='Leonides', page='NextSong', song='Believers'),
#  Row(userId='724', firstname='Isaiah', page='NextSong', song='Booksmart Devil'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Amazing Again'),
#  Row(userId='2872', firstname='Kevin', page='NextSong', song='Ghost of a Rose (re recorded new version)'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Hochmah (Interlude)'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song="We Don't Stop (Explicit)"),
#  Row(userId='1176', firstname='Justin', page='NextSong', song="Sugar_ We're Goin Down"),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Me About You'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Bananeira'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Almarita'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Heaven'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Dumb Blood'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='O Malandro Era Forte'),
#  Row(userId='2028', firstname='Ivan', page='NextSong', song='Hero (Album Version)'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Valerie'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song="Let's Build A Home (Album Version)"),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='All Is Love'),
#  Row(userId='1630', firstname='Katelynn', page='NextSong', song="Ghosts 'n' Stuff (Original Instrumental Mix)"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='The General'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Fred Jones Part 2'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song="Don't Smoke In Bed"),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Mockingbird'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='II'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='CanciÃ\x83Â³n Para Luchar'),
#  Row(userId='2028', firstname='Ivan', page='NextSong', song='Stuck In The Moment'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Scissors (Album Version)'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='What Your Soul Sings'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Links 2 3 4'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Bewildered'),
#  Row(userId='2963', firstname='Diego', page='NextSong', song='California Waiting'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song="When You're Gone"),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Shady Lady'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='HÃ\x83Â©roe De Leyenda (VersiÃ\x83Â³n Maxi)'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Gypsy Death And You'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Evolution Revolution Love (Album version)'),
#  Row(userId='2028', firstname='Ivan', page='NextSong', song='Survival'),
#  Row(userId='1855', firstname='Bryce', page='NextSong', song='Deuce'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Questions'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Angel On My Shoulder (EDX Radio Edit)'),
#  Row(userId='2963', firstname='Diego', page='NextSong', song="Sensiz istanbul'a dÃ\x83Â¼smanim"),
#  Row(userId='1362', firstname='Timothy', page='NextSong', song='Every Planet We Reach Is Dead'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song="Gimme All Your Lovin' (LP Version)"),
#  Row(userId='422', firstname='Talia', page='NextSong', song="Rockin' Robin"),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Take This To Heart (Album)'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Get Over It'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Move Your Body'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song="Don't Stop The Music"),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Mina FÃ\x83Â¤ders Hall'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Examples Of Things Not To Do In Bed (skit)'),
#  Row(userId='1855', firstname='Bryce', page='NextSong', song='Incredibad'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Better Off Alone'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='ARCHA (LIVE)'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Bad Company'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Sinister Kid'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song="'Till I Collapse"),
#  Row(userId='2963', firstname='Diego', page='NextSong', song='Refuse / Resist'),
#  Row(userId='1362', firstname='Timothy', page='NextSong', song='Wrap My Words Around You'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Whatcha Say'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Set Down Your Glass'),
#  Row(userId='2168', firstname='Saanvi', page='NextSong', song='The Akara'),
#  Row(userId='1168', firstname='Amen', page='NextSong', song='Death On Two Legs (Dedicated To....) (Live) (1994 Digital Remaster)'),
#  Row(userId='1855', firstname='Bryce', page='NextSong', song='Alice Practise'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Little Bird'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song="You're The One"),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song="Never Let 'Em C U Sweat"),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Sexy Bitch'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Rememo'),
#  Row(userId='1855', firstname='Bryce', page='NextSong', song='The Look Of Love'),
#  Row(userId='1168', firstname='Amen', page='NextSong', song='Struggle'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Risingson'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song="We Gon' Fight"),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Riot In Cell Block Number Nine'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='The Final Hour'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Entering White Cecilia'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Secrets'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Pepper'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Flowers On The Wall'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='I Got Cash'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Lost Cause'),
#  Row(userId='1855', firstname='Bryce', page='NextSong', song='Boys Will Be Boys'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Yellow'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Word Up!'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song="It's A Sin To Tell A Lie"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Piccolo Cesare'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Interlude'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Revolving Door'),
#  Row(userId='1282', firstname='Amaury', page='NextSong', song='Gives You Hell'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Coldwater Canyon'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Remember His Name'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='My Strange Uncles From Abroad'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Mr. Jones'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='High Times'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Nowhere To Go'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Down The Line'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='The Voiceless'),
#  Row(userId='1282', firstname='Amaury', page='NextSong', song='Sweet home Alabama'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', song='Last Christmas (Album Version)'),
#  Row(userId='362', firstname='Victoria', page='NextSong', song='Golden Skans'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Rayando el sol'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Hallelujah'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Mailbox Arson'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Ave Maria No Morro'),
#  Row(userId='1176', firstname='Justin', page='NextSong', song='Invisible Sun'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Testify'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Final Day'),
#  Row(userId='362', firstname='Victoria', page='NextSong', song='End Of The Road'),
#  Row(userId='776', firstname='Jenni', page='NextSong', song='Before Tomorrow Comes'),
#  Row(userId='2449', firstname='Jazmyne', page='NextSong', song='Girl Money'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Show Me'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='3AM (LP Version)'),
#  Row(userId='1955', firstname='Jaelyn', page='NextSong', song='Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edited Album Version)'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Ti si ~elja mog ~ivota'),
#  Row(userId='2913', firstname='Alexandra', page='NextSong', song='The Maestro'),
#  Row(userId='2232', firstname='Miguel', page='NextSong', song='Better Than (Album Version)'),
#  Row(userId='2892', firstname='Jordan', page='NextSong', song='Whistle For The Choir'),
#  Row(userId='2680', firstname='Daryl', page='NextSong', song='Makembe'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='The Humpty Dumpty Love Song'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Lotion (LP Version)'),
#  Row(userId='2910', firstname='Jaiden', page='NextSong', song='Losing Touch'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Ray Gun'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='My Night With the Prostitute From Marseille'),
#  Row(userId='2449', firstname='Jazmyne', page='NextSong', song='Breakdown'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Taylor'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Walk On The Water'),
#  Row(userId='1872', firstname='Austin', page='NextSong', song="I CAN'T GET STARTED"),
#  Row(userId='2232', firstname='Miguel', page='NextSong', song='Home (Album)'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Thrills'),
#  Row(userId='2910', firstname='Jaiden', page='NextSong', song='Greece 2000'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Young'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song="THIS ONE'S FOR YOU"),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='Your Song'),
#  Row(userId='2935', firstname='Emory', page='NextSong', song='Pro Dia Nascer Feliz'),
#  Row(userId='2867', firstname='Andrew', page='NextSong', song='Rattlesnake                (Snakes In The Playground Album Version)'),
#  Row(userId='1209', firstname='Damont', page='NextSong', song='Clocks'),
#  Row(userId='541', firstname='Angel', page='NextSong', song='Strut (1993 Digital Remaster)'),
#  Row(userId='1232', firstname='Dreden', page='NextSong', song='Yo Naci Para Amarte'),
#  Row(userId='2164', firstname='Zoie', page='NextSong', song='Billionaire [feat. Bruno Mars]  (Explicit Album Version)'),
#  Row(userId='2910', firstname='Jaiden', page='NextSong', song='The Go Getter'),
#  Row(userId='58', firstname='Enrique', page='NextSong', song='Empire State Of Mind (Part II) Broken Down'),
#  Row(userId='526', firstname='Bryleigh', page='NextSong', song='Bitter Sweet Symphony'),
#  Row(userId='2593', firstname='Rashaan', page='NextSong', song='Reptilia'),
#  Row(userId='1497', firstname='Noel', page='NextSong', song='With You'),
#  Row(userId='2935', firstname='Emory', page='NextSong', song='The Laws Have Changed'),
#  ...]

# %% [markdown]
# # Calculating Statistics by Hour

# %%
get_hour = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0). hour)

# %%
user_log = user_log.withColumn("hour", get_hour(user_log.ts))

# %%
user_log.head()
# Out:
# Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='22')

# %%
songs_in_hour = user_log.filter(user_log.page=='NextSong').groupby(user_log.hour).count().orderBy(user_log.hour.cast('float'))

# %%
songs_in_hour = user_log.filter(user_log.page == "NextSong").groupby(user_log.hour).count().orderBy(user_log.hour.cast("float"))

# %%
songs_in_hour.show()
# Out:
# +----+-----+
# |hour|count|
# +----+-----+
# |   0|  456|
# |   1|  454|
# |   2|  382|
# |   3|  302|
# |   4|  352|
# |   5|  276|
# |   6|  348|
# |   7|  358|
# |   8|  375|
# |   9|  249|
# |  10|  216|
# |  11|  228|
# |  12|  251|
# |  13|  339|
# |  14|  462|
# |  15|  479|
# |  16|  484|
# |  17|  430|
# |  18|  362|
# |  19|  295|
# +----+-----+
# only showing top 20 rows

# %%
songs_in_hour_pd = songs_in_hour.toPandas()
songs_in_hour_pd.hour = pd.to_numeric(songs_in_hour_pd.hour)

# %%
type(songs_in_hour_pd.hour)
# Out:
# pandas.core.series.Series

# %%
plt.scatter(songs_in_hour_pd["hour"], songs_in_hour_pd["count"])
plt.xlim(-1, 24);
plt.ylim(0, 1.2 * max(songs_in_hour_pd["count"]))
plt.xlabel("Hour")
plt.ylabel("Songs played");

# %% [markdown]
# # Drop Rows with Missing Values
#
# As you'll see, it turns out there are no missing values in the userID or session columns. But there are userID values that are empty strings.

# %%
user_log_valid = user_log.dropna(how = "any", subset = ["userId", "sessionId"])

# %%
user_log_valid.count()
# Out:
# 10000

# %%
user_log.select("userId").dropDuplicates().sort("userId").show()
# Out:
# +------+
# |userId|
# +------+
# |      |
# |    10|
# |   100|
# |  1000|
# |  1003|
# |  1005|
# |  1006|
# |  1017|
# |  1019|
# |  1020|
# |  1022|
# |  1025|
# |  1030|
# |  1035|
# |  1037|
# |   104|
# |  1040|
# |  1042|
# |  1043|
# |  1046|
# +------+
# only showing top 20 rows

# %%
user_log_valid = user_log_valid.filter(user_log_valid["userId"] != "")

# %%
user_log_valid.count()
# Out:
# 9664

# %% [markdown]
# # Users Downgrade Their Accounts
#
# Find when users downgrade their accounts and then flag those log entries. Then use a window function and cumulative sum to distinguish each user's data as either pre or post downgrade events.

# %%
user_log_valid.filter("page = 'Submit Downgrade'").show()
# Out:
# +------+---------+---------+------+-------------+--------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |artist|     auth|firstName|gender|itemInSession|lastName|length|level|            location|method|            page| registration|sessionId|song|status|           ts|           userAgent|userId|hour|
# +------+---------+---------+------+-------------+--------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+
# |  null|Logged In|    Kelly|     F|           24|  Newton|  null| paid|Houston-The Woodl...|   PUT|Submit Downgrade|1513283366284|     5931|null|   307|1513768454284|Mozilla/5.0 (Wind...|  1138|  11|
# +------+---------+---------+------+-------------+--------+------+-----+--------------------+------+----------------+-------------+---------+----+------+-------------+--------------------+------+----+

# %%
user_log.select(["userId", "firstname", "page", "level", "song"]).where(user_log.userId == "1138").collect()
# Out:
# [Row(userId='1138', firstname='Kelly', page='Home', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Everybody Everybody'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Gears'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Use Somebody'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Love Of My Life (1993 Digital Remaster)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Down In The Valley Woe'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Treat Her Like A Lady'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="Everybody Thinks You're An Angel"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Fourteen Wives'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Love On The Rocks'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Breakeven'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Leaf House'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='NAISEN KANSSA'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="You're In My Heart"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Roll On Down The Highway'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Plasticities (Remix)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Secrets'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Hello'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='I Never Told You'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Love Break Me'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='One Touch One Bounce'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Undo'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Overdue (Blackbeard Remix)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Slave To Love (1999 Digital Remaster)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Stronger'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='All Of Us (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Sehr kosmisch'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='March Of The Celts'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Electricity'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Aces High'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Bananeira'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='The General'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='HÃ\x83Â©roe De Leyenda (VersiÃ\x83Â³n Maxi)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="Don't Stop The Music"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="You're The One"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Entering White Cecilia'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Piccolo Cesare'),
#  Row(userId='1138', firstname='Kelly', page='Help', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Last Christmas (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='You Shook Me'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Going Steady'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='My Name Is'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Undo'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Secrets'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Good Times Gone (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Angelito'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Batdance ( LP Version )'),
#  Row(userId='1138', firstname='Kelly', page='Home', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='DiÃ\x83Â¡kdal'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Whirring'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Potholderz (feat. Count Bass D)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Seaside'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Louder Than A Bomb'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Just Like You'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="You're The One"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Turn It Again (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Everywhere I Go'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song="Easy Skankin'"),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Roses'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Killing Me Softly With His Song'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='The Razor (Album Version)'),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='paid', song='Idols and Anchors'),
#  Row(userId='1138', firstname='Kelly', page='Downgrade', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='Submit Downgrade', level='paid', song=None),
#  Row(userId='1138', firstname='Kelly', page='Home', level='free', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='free', song='Bones'),
#  Row(userId='1138', firstname='Kelly', page='Home', level='free', song=None),
#  Row(userId='1138', firstname='Kelly', page='NextSong', level='free', song='Grenouilles Mantidactylus (Small Frogs)')]

# %%
flag_downgrade_event = udf(lambda x: 1 if x == "Submit Downgrade" else 0, IntegerType())

# %%
user_log_valid = user_log_valid.withColumn("downgraded", flag_downgrade_event("page"))

# %%
user_log_valid.head()
# Out:
# Row(artist='Showaddywaddy', auth='Logged In', firstName='Kenneth', gender='M', itemInSession=112, lastName='Matthews', length=232.93342, level='paid', location='Charlotte-Concord-Gastonia, NC-SC', method='PUT', page='NextSong', registration=1509380319284, sessionId=5132, song='Christmas Tears Will Fall', status=200, ts=1513720872284, userAgent='"Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"', userId='1046', hour='22', downgraded=0)

# %%
from pyspark.sql import Window

# %%
windowval = Window.partitionBy("userId").orderBy(desc("ts")).rangeBetween(Window.unboundedPreceding, 0)

# %%
user_log_valid = user_log_valid.withColumn("phase", Fsum("downgraded").over(windowval))

# %%
user_log_valid.select(["userId", "firstname", "ts", "page", "level", "phase"]).where(user_log.userId == "1138").sort("ts").collect()
# Out:
# [Row(userId='1138', firstname='Kelly', ts=1513729066284, page='Home', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513729066284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513729313284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513729552284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513729783284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513730001284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513730263284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513730518284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513730768284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513731182284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513731435284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513731695284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513731857284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513732160284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513732302284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513732540284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513732770284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513732994284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513733223284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513733456284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513733738284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513733941284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513734289284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513734598284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513734863284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513735174284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513735385284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513736040284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513736237284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513736446284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513736709284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513736915284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513737160284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513737460284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513737728284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513737936284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513738144284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513738197284, page='Help', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513738432284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513763195284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513763453284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513763622284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513763890284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513764238284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513764462284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513764782284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513765075284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513765075284, page='Home', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513765448284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513765655284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513765818284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513766091284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513766189284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513766385284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513766599284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513766838284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513767203284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513767413284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513767643284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768012284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768242284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768452284, page='NextSong', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768453284, page='Downgrade', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768454284, page='Submit Downgrade', level='paid', phase=1),
#  Row(userId='1138', firstname='Kelly', ts=1513768456284, page='Home', level='free', phase=0),
#  Row(userId='1138', firstname='Kelly', ts=1513814880284, page='NextSong', level='free', phase=0),
#  Row(userId='1138', firstname='Kelly', ts=1513821430284, page='Home', level='free', phase=0),
#  Row(userId='1138', firstname='Kelly', ts=1513833144284, page='NextSong', level='free', phase=0)]
